# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')

# %cd drive/MyDrive/elomia
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/elomia

# %%
# !pip install -U sentence-transformers
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 79 kB 3.9 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 19.8 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 46.0 MB/s
# ...
#      |████████████████████████████████| 77 kB 6.6 MB/s
# ...
#      |████████████████████████████████| 895 kB 43.8 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 36.6 MB/s
# ...
#      |████████████████████████████████| 596 kB 53.0 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=b3b8f35f19a4deed22a7f9a9fa175bc631d4ec4052cd535752de904fa3ced9e3
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
# Successfully built sentence-transformers
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from API.inferer import Inferer

# %%
ok_w_path="bert_logs/initial/checkpoints"
neok_w_path = "bert_logs/withoutneok/checkpoints"

inferer = Inferer(ok_cls_model_weights_path=ok_w_path,
                  neok_cls_model_weights_path=neok_w_path,
                  description_texts_path="exercises_descriptions")
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/607 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/313M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/148 [00:00<?, ?B/s]
# ...

# %%
result = inferer.run_inference("I like to think about you but I hate myself because you don't like me")

# %%
print(result.id)
print(result.text)

print(result.embs.shape)

print(result.ok_iscalm_preds) # trained on all calms
print(result.neok_iscalm_preds) # trained on calms with filtered ne ok
print(result.desc_sim_dict)
# Out:
# 1649266847.551305
# I like to think about you but I hate myself because you don't like me
# (768,)
# 0.82113206
# 0.45505786
# {'ideal_relationship': 0.041385297, 'after_break': 0.7325789, 'love_yourself': 0.4454208, 'lose_weight': 0.5171665, 'calm_down': 0.7223727, 'fall_asleep': 0.7045739, 'increase_happines': 0.6044333, 'make_a_decision': 0.35050213, 'stop_anxiety': 0.3843039, 'boost_productivity': 0.56621706, 'stop_procrastinating': 0.571744}
