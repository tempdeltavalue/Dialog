# %%
# !pip install -U dm-haiku
# !pip install optax
# Out:
# ...
#      |████████████████████████████████| 309 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 136 kB 8.3 MB/s
# ...
#      |████████████████████████████████| 72 kB 966 kB/s
# ...

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/elomia/jax
# Out:
# /content/drive/MyDrive/elomia/jax

# %%
# import unicodedata
# with open("test_ex.txt", 'r') as f:
#   corpus = f.read()

# corpus = unicodedata.normalize('NFKD', corpus).encode('ascii','ignore')

# !python3 transformer_ex/train.py --dataset_path="test_ex.txt" --alsologtostderr
# Out:
# Traceback (most recent call last):
#   File "transformer_ex/train.py", line 42, in <module>
#     from transformer_ex import dataset
# ModuleNotFoundError: No module named 'transformer_ex'

# %%
if not corpus.isascii():
  raise ValueError('Loaded corpus is not ASCII.')

# %%
corpus
# Out:
# b',,/ ,\nThe argument was about her ex-friend I tried to take up for her but she just started cursing at me. I think she reacted this way because she also said you and my ex bsf can be friends then I tried helping her taking up for her and I think she just went mad we argued on discord a very bad app for people we argued in front of 100 people. I feel sad and frustrated about this situation.,CalmDownExercise, ,\n" I wanted to do my nails because just like 39 minutes ago I wanted to do my nails but I couldn\'t do it because I started crying and going all manic. I have no hobbies because it makes me feel better about my fat ass fingers. No, I don\'t like to do any hobbies.",IncreaseHappinessExercise, ,\nI am upset. I have been feeling upset.  It is not fair I think.,IncreaseHappinessExercise, ,\n" I know hes unwell because I spoke to him recently. So I know thats true. But I dont know if hes unwell enough not to see me. As I said before, Im scared to confront him with my suspicions. If
# ...
